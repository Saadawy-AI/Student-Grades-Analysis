# %%
pip install pandas matplotlib seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# إعداد العرض
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# تحميل البيانات
df = pd.read_csv("Student Grades.csv")

# ----------- إحصاءات عامة -----------

print("\n📊 إحصائيات وصفية:\n", df.describe())

# قائمة المواد
subjects = ["Math", "Physics", "Chemistry", "English", "Biology", "History"]

# ----------- Histogram لكل مادة -----------
for subject in subjects:
    plt.figure()
    sns.histplot(df[subject], kde=True, bins=10, color='skyblue')
    plt.title(f'Distribution of Grades in {subject}')
    plt.xlabel('Grade')
    plt.ylabel('Number of Students')
    plt.grid(True)
    plt.show()

# ----------- Boxplot مقارنة بين المواد -----------
plt.figure()
sns.boxplot(data=df[subjects])
plt.title("Boxplot of Grades for All Subjects")
plt.xticks(rotation=45)
plt.show()

# ----------- Heatmap لعلاقة المواد ببعضها -----------
plt.figure()
corr_matrix = df[subjects].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation between Subjects")
plt.show()

# ----------- Barplot توزيع التقديرات الحرفية -----------
plt.figure()
sns.countplot(x='Grade Letter', data=df, order=['A', 'B', 'C', 'D', 'E', 'F'], palette='Set2')
plt.title("Distribution of Grade Letters")
plt.xlabel("Grade Letter")
plt.ylabel("Number of Students")
plt.show()

# ----------- Pie chart لنسب التقديرات الحرفية -----------
plt.figure()
grade_counts = df['Grade Letter'].value_counts().sort_index()
plt.pie(grade_counts, labels=grade_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel"))
plt.title("Grade Letter Distribution")
plt.axis('equal')
plt.show()

# ----------- Barplot لعدد الساعات المسموحة حسب التقدير -----------
plt.figure()
sns.boxplot(x='Grade Letter', y='Allowed Hours Next Semester', data=df, order=['A', 'B', 'C', 'D', 'E', 'F'])
plt.title("Allowed Hours by Grade Letter")
plt.show()

# ----------- Pairplot لعلاقات المواد ببعضها -----------
sns.pairplot(df[subjects + ['Final Grade']])
plt.suptitle("Pairwise Relationships Between Subjects", y=1.02)
plt.show()

# ----------- خط بياني لمقارنة درجات كل طالب عبر المواد -----------
plt.figure(figsize=(14, 6))
for i, row in df.iterrows():
    plt.plot(subjects, row[subjects], marker='o', label=row['Name'])
plt.title("Student Grades Across All Subjects")
plt.xlabel("Subjects")
plt.ylabel("Grades")
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.tight_layout()
plt.show()
# Out:
# 📊 إحصائيات وصفية:
#         Student_ID       Math    Physics   Chemistry    English    Biology  \
# count   18.000000  18.000000  18.000000   18.000000  18.000000  18.000000
# mean     9.500000  73.166667  74.000000   74.111111  70.611111  68.055556
# std      5.338539  18.582883  18.333512   19.155368  18.372418  17.962288
# min      1.000000  40.000000  40.000000   40.000000  40.000000  40.000000
# 25%      5.250000  66.000000  65.250000   65.250000  60.500000  54.000000
# 50%      9.500000  76.500000  78.500000   79.000000  70.000000  70.500000
# 75%     13.750000  84.750000  89.250000   89.000000  85.250000  84.250000
# max     18.000000  98.000000  93.000000  100.000000  99.000000  92.000000
#
#          History  Final Grade  Registered Hours  Allowed Hours Next Semester
# count  18.000000    18.000000              18.0                    18.000000
# mean   72.444444    72.055556              18.0                    18.000000
# ...
